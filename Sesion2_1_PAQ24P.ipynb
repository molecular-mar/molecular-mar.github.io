# %% [markdown]
# <a href="https://colab.research.google.com/github/molecular-mar/molecular-mar.github.io/blob/master/Sesion2_1_PAQ24P.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Principios de programación 1
# ---

# %% [markdown]
# **Nota**: En los Notebooks encontrarás una serie de ejercicios, señalados por el símbolo ❓. **Debes realizarlos durante clase, ya que se considerarán como parte de tu participación**.
#
# ---

# %% [markdown]
# ## ¿Cómo funciona Colab?
#
# Cuando ejecutamos/corremos código de Python, se nos da acceso a una *computadora* a distancia/de forma remota. Nota en la esquina superior derecha, como cambiamos de:

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# #a:

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# ❓¿Cuánto disco y RAM te "presta" Colab?

# %% [markdown]
# **IMPORTANTE**. El tiempo de ejecución es limitado. Si tu sesión pasa demasiado tiempo inactiva, se cerrará la conexión al equipo virtual.
#
# *no ofrece recursos garantizados ni ilimitados(...) los límites de uso generales, los tiempos de espera por inactividad, la duración máxima de las máquinas virtuales, los tipos de GPU disponibles y otros factores pueden variar a lo largo del tiempo.*

# %% [markdown]
# ❓ Registra en un bloque de texto dos formas de *evaluar/ejecutar* la celda de código.

# %% [markdown]
# ### Para ejecutar una celda de código:

# %% [markdown]
# ## Aritmética
#
# En Python podemos realizar operaciones aritméticas, tal y como si trabajaramos con una calculadora. Para ello, comencemos a hacer uso de bloques de código. Para crear un bloque de código, utiliza el botón `+ Código` que aparece en la parte superior (debajo del menú Archivo) o al colocarte en el límite de otro bloque.

# %% [markdown]
# Ahora, veamos como Python funciona como una calculadora.
#
# La siguiente tabla muestra algunas de las operaciones aritméticas que podemos realizar:
#
# |Operación|Operador|
# |:---:|:---:|
# |Suma|+|
# |Resta|-|
# |Multiplicación|*|
# |División|/|
# |División entera|//|
# |Potencia|**|
# |Módulo|%|
#
# ❓ Realiza pruebas en celdas/bloques de código separadas. Agrega bloques de texto que te ayuden a comprender las operaciones nuevas.

# %%
48+10

# %%
50 - 10

# %%
5*10

# %%
7/2

# %%
7//2

# %%
7%2

# %% [markdown]
# Hay un orden de evaluación de las operaciones. Y al igual que en las operaciones matemáticas, podemos agrupar usando paréntesis.
#
# Ejemplo: $$3+((5-2)/2))$$
#
# ❓Escribe cuál es el ordén típico de las operaciones. Luego, en celdas separadas verifica si este orden es respetado en Python. Anota tus observaciones en comentarios:

# %%
# Los comentarios comienzan por un gato en los bloques de código.

# %% [markdown]
# ❓¿Cuánto será el resultado de la expresión $8/2*(2+2)$? ¿Dónde deberías incluir paréntesis para que de como resultado 1? Sin los paréntesis, ¿te sería fácil evaluar amabas expresiones?

# %% [markdown]
# ### *Extra*:
# En Python, existen algunas *convenciones* de formato estándar, que buscan mejorar la lectura del código. Una de ellas es separar por un espacio al operador de sus operandos:
#
#
#
# ```python
# 3 + 3 - (5 * 10) #Nota los espacios. También, nota la ubicación de este comentario
# ```

# %% [markdown]
# ## Tipos numéricos: int y float
#
# ❓ Intenta las siguientes operaciones en bloques de código separados. Documenta tus observaciones.
#
# * 3*6
# * 3.0*6
# * 2/3
# * (7+8)/12

# %% [markdown]
# En una computadora, los números *enteros* y los *reales* se representan de formas diferentes.
#
# A un dato numérico entero se les conoce como ``` int ```, y a un número real como ``` float ``` (en español, se les dice *de punto flotante*).
#
# En general, los ```int``` requieren menos memoria que los ```float```.
#
# Nota: En Python es posible utilizar notación científica. Por ejemplo, el número de Avogadro se escribe como `6.022E23`.
#
# ❓Determina el número de átomos en 3.5 moles de C.
#
# ---

# %% [markdown]
# ## Algunas funciones aritméticas básicas
#
# Otras operaciones matemáticas aparecen como *funciones*. Recordemos las funciones matemáticas:
# $f(x)=y,$
# donde *f* es la función, *x* el argumento y, en este contexto, llamaremos a *y* como resultado. De forma análoga, una función en Python acepta uno o varios argumentos, y regresa uno o varios resultados. Lo veremos a detalle más adelante.
#
# ❓ Prueba las siguientes funciones, usando celdas de código individuales y probando con números enteros y reales.
#
# ```python
# abs()
# round()
# ```

# %% [markdown]
# Existen funciones que cambian el tipo numérico de un dato.```int()``` convierte a tipo entero. ```float()``` a tipo flotante. Para verificar de qué tipo es un dato, podemos usar la función `type()`
#
# ❓ Prueba ambas funciones en celdas de código. ¿Qué tipo de datos son los siguientes?:
#
# * 11 Matraces
# * Número de Avogadro
# * Número de Euler
# * 2 pizzas y media
# * 20 followers

# %% [markdown]
# ## Tarea
#
# En un nuevo notebook, escribe un documento que contenga lo siguiente:
#
# * Cinco ejemplos de cantidades que puedan escribirse usando enteros, con al menos 3 cantidades asociadas a la Química.
#
# * Cinco ejemplos de cantidades que se escriban como tipo flotante, con al menos 3 cantidades asociadas a la Química.
#
# Cada ejemplo debe estar justificado (¿Por qué no escribirlo con el otro tipo, o por qué es más conveniente el que elegiste?). Incluye al menos una operación algebraica por cada ejemplo en un bloque de código y ejecutala, haciendo uso al menos una vez de cada una de las operaciones revisadas.
#
# * Finalmente, escribe un bloque de texto describiendo las funciones revisadas (`abs`,`round`, `type`, `int`, `float`), y bloques de código donde hagas uso de las mismas.
